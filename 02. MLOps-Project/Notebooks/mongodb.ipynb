# %%
import pandas as pd

# %%
df = pd.read_csv("../heart_disease_prediction/healthcare-dataset-stroke-data.csv")
# print(dataset.to_string())

print(df.head())
print(df.shape)
print(df.columns)
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
# (5110, 12)
# ...

# %%
data = df.to_dict(orient="records")

# %%
len(data)
# Out:
# 5110

# %%
data[0]['age']
# Out:
# 67.0

# %%
DB_NAME = 'heart_disease'
COLLECTION_NAME = "stroke_data"
CONNECTION_URL = 'mongodb+srv://iamanasinam:123456Anas@cluster0.pb6rez9.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'

# %%
import pymongo as pm

# %%
client = pm.MongoClient(CONNECTION_URL)
database = client[DB_NAME]
collection = database[COLLECTION_NAME]
record = collection.insert_many(data)

# %%
records = collection.find()
records

# %%
for i, j in enumerate(records):
    print(f"Record Number, {i}: {j}")
# Out:
# Record Number, 0: {'_id': ObjectId('66a7253dc42fa34a5afb3ee7'), 'id': 9046, 'gender': 'Male', 'age': 67.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 228.69, 'bmi': 36.6, 'smoking_status': 'formerly smoked', 'stroke': 1}
# Record Number, 1: {'_id': ObjectId('66a7253dc42fa34a5afb3ee8'), 'id': 51676, 'gender': 'Female', 'age': 61.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Rural', 'avg_glucose_level': 202.21, 'bmi': nan, 'smoking_status': 'never smoked', 'stroke': 1}
# Record Number, 2: {'_id': ObjectId('66a7253dc42fa34a5afb3ee9'), 'id': 31112, 'gender': 'Male', 'age': 80.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 105.92, 'bmi': 32.5, 'smoking_status': 'never smoked', 'stroke': 1}
# ...

# %%
df = pd.DataFrame(list(collection.find()))
df.head()
# print(df.columns)
# Out:
#                         _id     id  gender   age  hypertension  heart_disease  \
# 0  66a7253dc42fa34a5afb3ee7   9046    Male  67.0             0              1
# 1  66a7253dc42fa34a5afb3ee8  51676  Female  61.0             0              0
# 2  66a7253dc42fa34a5afb3ee9  31112    Male  80.0             0              1
# 3  66a7253dc42fa34a5afb3eea  60182  Female  49.0             0              0
# 4  66a7253dc42fa34a5afb3eeb   1665  Female  79.0             1              0
#
#   ever_married      work_type Residence_type  avg_glucose_level   bmi  \
# 0          Yes        Private          Urban             228.69  36.6
# 1          Yes  Self-employed          Rural             202.21   NaN
# 2          Yes        Private          Rural             105.92  32.5
# 3          Yes        Private          Urban             171.23  34.4
# 4          Yes  Self-employed          Rural             174.12  24.0
#
#     smoking_status  stroke
# 0  formerly smoked       1
# ...
